# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

# %%
race_df = pd.read_csv('F1Drivers_Dataset.csv')
race_df
# Out:
#                 Driver     Nationality                         Seasons  \
# 0          Carlo Abate           Italy                    [1962, 1963]
# 1     George Abecassis  United Kingdom                    [1951, 1952]
# 2        Kenny Acheson  United Kingdom                    [1983, 1985]
# 3    Andrea de Adamich           Italy  [1968, 1970, 1971, 1972, 1973]
# 4       Philippe Adams         Belgium                          [1994]
# ..                 ...             ...                             ...
# 863      Emilio Zapico           Spain                          [1976]
# 864        Zhou Guanyu           China                          [2022]
# 865      Ricardo Zonta          Brazil  [1999, 2000, 2001, 2004, 2005]
# 866        Renzo Zorzi           Italy              [1975, 1976, 1977]
# 867     Ricardo Zunino       Argentina              [1979, 1980, 1981]
#
#      Championships  Race_Entries  Race_Starts  Pole_Positions  Race_Wins  \
# ...

# %%
race_df_clean = race_df.dropna()
print (race_df_clean)
# Out:
#                  Driver     Nationality  \
# 17      Fernando Alonso           Spain
# 25       Mario Andretti   United States
# 35       Alberto Ascari           Italy
# 107        Jack Brabham       Australia
# 135       Jenson Button  United Kingdom
# 169           Jim Clark  United Kingdom
# 238  Juan Manuel Fangio       Argentina
# 239         Nino Farina           Italy
# 250  Emerson Fittipaldi          Brazil
# 334       Mika Häkkinen         Finland
# 338      Lewis Hamilton  United Kingdom
# 351       Mike Hawthorn  United Kingdom
# 363          Damon Hill  United Kingdom
# 364         Graham Hill  United Kingdom
# 365           Phil Hill   United States
# 376         Denny Hulme     New Zealand
# 377          James Hunt  United Kingdom
# 397          Alan Jones       Australia
# 442          Niki Lauda         Austria
# 489       Nigel Mansell  United Kingdom
# 612       Nelson Piquet          Brazil
# 628         Alain Prost          France
# ...

# %%
country_org = race_df_clean.groupby('Nationality').mean(numeric_only=True)
country_org
# Out:
#                 Championships  Race_Entries  Race_Starts  Pole_Positions  \
# Nationality
# Argentina            5.000000     52.000000    51.000000       29.000000
# Australia            2.000000    122.500000   121.000000        9.500000
# Austria              2.000000    119.500000   115.500000       17.000000
# Brazil               2.666667    172.666667   169.666667       31.666667
# Canada               1.000000    165.000000   163.000000       13.000000
# Finland              1.333333    215.333333   208.000000       16.333333
# France               4.000000    202.000000   199.000000       33.000000
# Germany              4.000000    271.333333   270.333333       51.666667
# Italy                1.500000     33.500000    32.500000        9.500000
# Netherlands          2.000000    164.000000   164.000000       21.000000
# New Zealand          1.000000    112.000000   112.000000        1.000000
# South Africa         1.000000    113.000000   112.000000        3.000000
# ...

# %%
country_org.plot(kind='bar', figsize=(10,5))
# Out:
# <Axes: xlabel='Nationality'>
